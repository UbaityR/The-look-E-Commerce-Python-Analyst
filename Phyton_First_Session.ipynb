# %% [markdown]
# # Koneksi ke Bigquery

# %%
from google.colab import auth
from google.cloud import bigquery

# %%
auth.authenticate_user()
PROJECT_ID = "my-project-2602-505412"
client = bigquery.Client(project=PROJECT_ID)
print("Connected:", PROJECT_ID)
# Out:
# Connected: my-project-2602-505412

# %% [markdown]
# #Cek Tabel TheLook E-commerce

# %%
query = '''
SELECT table_name
FROM `bigquery-public-data.thelook_ecommerce.INFORMATION_SCHEMA.TABLES`
ORDER BY table_name
'''
client.query(query).to_dataframe()
# Out:
#              table_name
# 0  distribution_centers
# 1                events
# 2       inventory_items
# 3           order_items
# 4                orders
# 5              products
# 6                 users

# %% [markdown]
# #Case Study

# %% [markdown]
# Tampilkan seluruh tabel order!

# %%
query_1 = '''
SELECT *
FROM `bigquery-public-data.thelook_ecommerce.orders`
'''
client.query(query_1).to_dataframe()
# Out:
#         order_id  user_id     status gender                created_at  \
# 0             30       28  Cancelled      F 2026-06-01 11:14:10+00:00
# 1             32       30  Cancelled      F 2025-06-15 09:08:43+00:00
# 2             65       56  Cancelled      F 2025-02-20 08:23:48+00:00
# 3             94       83  Cancelled      F 2025-11-24 12:38:01+00:00
# 4            109       95  Cancelled      F 2024-07-17 14:04:48+00:00
# ...          ...      ...        ...    ...                       ...
# 124716    124702    99980    Shipped      M 2026-01-25 09:31:39+00:00
# 124717    124708    99985    Shipped      M 2026-07-23 19:09:55+00:00
# 124718    124709    99986    Shipped      M 2026-02-15 04:04:07+00:00
# 124719    124710    99987    Shipped      M 2024-08-24 13:06:12+00:00
# 124720    124718    99998    Shipped      M 2026-07-15 23:37:36+00:00
#
#        returned_at                shipped_at delivered_at  num_of_item
# ...

# %%
df_orders = client.query(query_1).to_dataframe()

# %%
df_orders.head ()
# Out:
#    order_id  user_id     status gender                created_at returned_at  \
# 0        30       28  Cancelled      F 2026-06-01 11:14:10+00:00         NaT
# 1        32       30  Cancelled      F 2025-06-15 09:08:43+00:00         NaT
# 2        65       56  Cancelled      F 2025-02-20 08:23:48+00:00         NaT
# 3        94       83  Cancelled      F 2025-11-24 12:38:01+00:00         NaT
# 4       109       95  Cancelled      F 2024-07-17 14:04:48+00:00         NaT
#
#   shipped_at delivered_at  num_of_item
# 0        NaT          NaT            1
# 1        NaT          NaT            1
# 2        NaT          NaT            3
# 3        NaT          NaT            3
# 4        NaT          NaT            1

# %% [markdown]
# #Exploratory Data Analyst

# %%
df_orders.shape
# Out:
# (124721, 9)

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124721 entries, 0 to 124720
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      124721 non-null  Int64
#  1   user_id       124721 non-null  Int64
#  2   status        124721 non-null  object
#  3   gender        124721 non-null  object
#  4   created_at    124721 non-null  datetime64[us, UTC]
#  5   returned_at   12376 non-null   datetime64[us, UTC]
#  6   shipped_at    81061 non-null   datetime64[us, UTC]
#  7   delivered_at  43528 non-null   datetime64[us, UTC]
#  8   num_of_item   124721 non-null  Int64
# dtypes: Int64(3), datetime64[us, UTC](4), object(2)
# memory usage: 8.9+ MB

# %% [markdown]
# #Filter

# %% [markdown]
# Hanya tampilkan status Complete

# %%
df_orders_filtered = df_orders[df_orders['status'] == 'Complete']

# %%
df_orders_filtered.head()
# Out:
#       order_id  user_id    status gender                created_at  \
# 9240        10        6  Complete      F 2026-07-31 11:21:33+00:00
# 9241        11        7  Complete      F 2024-11-02 03:54:34+00:00
# 9242        16       13  Complete      F 2024-04-18 21:54:35+00:00
# 9243        19       16  Complete      F 2023-07-04 21:03:15+00:00
# 9244        23       20  Complete      F 2026-04-18 23:09:53+00:00
#
#      returned_at                shipped_at              delivered_at  \
# 9240         NaT 2026-07-31 23:47:33+00:00 2026-08-05 15:13:33+00:00
# 9241         NaT 2024-11-04 15:54:34+00:00 2024-11-08 17:44:34+00:00
# 9242         NaT 2024-04-21 09:37:35+00:00 2024-04-23 19:12:35+00:00
# 9243         NaT 2023-07-06 11:47:15+00:00 2023-07-08 18:47:15+00:00
# 9244         NaT 2026-04-19 19:28:53+00:00 2026-04-23 08:05:53+00:00
#
#       num_of_item
# 9240            2
# 9241            1
# 9242            1
# 9243            2
# 9244            1

# %% [markdown]
# #TASK!

# %% [markdown]
# # Buat tabel df_users dimana tabel memuat kolom:
# Country,
# gender,
# total user

# %% [markdown]
# Kalau tabel df_users sudah muncul. buatlah filter gender hanya yang Female

# %%
from google.colab import auth
from google.cloud import bigquery

# %%
auth.authenticate_user()
PROJECT_ID = "my-project-2602-505412"
client = bigquery.Client(project=PROJECT_ID)
print("Connected:", PROJECT_ID)
# Out:
# Connected: my-project-2602-505412

# %%
query_2 = '''
SELECT *
FROM `bigquery-public-data.thelook_ecommerce.users`
'''
client.query(query_2).to_dataframe()
# Out:
#           id first_name last_name                          email  age gender  \
# 0      60622    Jeffrey   Herrera     jeffreyherrera@example.com   69      M
# 1      13500    Timothy   Stanley     timothystanley@example.net   59      M
# 2      22694  Charlotte  Williams  charlottewilliams@example.org   63      F
# 3      77067     Andrew    Flores       andrewflores@example.com   58      M
# 4      87343     George     Miles        georgemiles@example.org   70      M
# ...      ...        ...       ...                            ...  ...    ...
# 99995  24913      David     Davis         daviddavis@example.net   57      M
# 99996  81058    Melinda      Soto        melindasoto@example.com   16      F
# 99997   8747     Samuel  Figueroa     samuelfigueroa@example.com   12      M
# 99998  85671   Mitchell     Keith      mitchellkeith@example.net   55      M
# 99999  23341       John    Peters         johnpeters@example.org   19      M
#
# ...

# %%
df_users = client.query(query_2).to_dataframe()

# %%
df_users.head()
# Out:
#       id first_name last_name                          email  age gender  \
# 0  60622    Jeffrey   Herrera     jeffreyherrera@example.com   69      M
# 1  13500    Timothy   Stanley     timothystanley@example.net   59      M
# 2  22694  Charlotte  Williams  charlottewilliams@example.org   63      F
# 3  77067     Andrew    Flores       andrewflores@example.com   58      M
# 4  87343     George     Miles        georgemiles@example.org   70      M
#
#   state               street_address postal_code  city country  latitude  \
# 0  Acre   016 Whitaker Port Apt. 407   69980-000  null  Brasil -8.065346
# 1  Acre     17603 Christopher Radial   69980-000  null  Brasil -8.065346
# 2  Acre  4935 Barker Fords Suite 244   69980-000  null  Brasil -8.065346
# 3  Acre   63982 Frank Fall Suite 965   69980-000  null  Brasil -8.065346
# 4  Acre  1534 Stewart Crest Apt. 371   69980-000  null  Brasil -8.065346
#
#    longitude traffic_source                created_at  \
# ...

# %%
df_users.groupby(['country', 'gender'])['id'].count()
# Out:
# country         gender
# Australia       F          1040
#                 M          1099
# Austria         F             1
#                 M             2
# Belgium         F           628
#                 M           591
# Brasil          F          7357
#                 M          7230
# China           F         16923
#                 M         17057
# Colombia        F             4
#                 M             7
# España          F             1
#                 M             1
# France          F          2293
#                 M          2338
# Germany         F          2071
#                 M          2117
# Japan           F          1210
#                 M          1119
# Poland          F           102
#                 M           122
# South Korea     F          2718
#                 M          2718
# Spain           F          1956
#                 M          1955
# United Kingdom  F          2324
#                 M          2396
# ...

# %%
df_users_filtered = df_users[df_users['gender'] == 'F']

# %%
df_users_filtered.head()
# Out:
#        id first_name last_name                          email  age gender  \
# 2   22694  Charlotte  Williams  charlottewilliams@example.org   63      F
# 5   45900    Whitney   Russell     whitneyrussell@example.net   47      F
# 6     424    Natasha     Moore       natashamoore@example.net   14      F
# 13  25126    Deborah  Mcdaniel    deborahmcdaniel@example.org   21      F
# 14  26316    Kathryn     Arias       kathrynarias@example.net   42      F
#
#    state               street_address postal_code  city country  latitude  \
# 2   Acre  4935 Barker Fords Suite 244   69980-000  null  Brasil -8.065346
# 5   Acre   10986 John Walks Suite 371   69980-000  null  Brasil -8.065346
# 6   Acre   1651 Jessica Club Apt. 809   69980-000  null  Brasil -8.065346
# 13  Acre             1722 Ayers Drive   69980-000  null  Brasil -8.065346
# 14  Acre   1852 Gilbert Keys Apt. 960   69980-000  null  Brasil -8.065346
#
#     longitude traffic_source                created_at  \
# ...
